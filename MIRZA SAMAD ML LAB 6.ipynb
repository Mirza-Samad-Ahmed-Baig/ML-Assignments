# %% [markdown]
# # MIRZA SAMAD 1790-2020 BSAI
# # MACHINE LEARNING LAB TASK 6

# %%
# PERFORMING WEB SCRAPING
from bs4 import BeautifulSoup
import requests
import pandas as pd
df = pd.DataFrame({'Product_Title':[''], 'Price':[''], 'Rating':[''], 'Reviews':[''], 'Availability':['']})

# Function to extract Product Title
def get_title(soup):
	
	try:
		# Outer Tag Object
		title = soup.find("span", attrs={"id":'productTitle'})

		# Inner NavigatableString Object
		title_value = title.string

		# Title as a string value
		title_string = title_value.strip()

		# # Printing types of values for efficient understanding
		# print(type(title))
		# print(type(title_value))
		# print(type(title_string))
		# print()

	except AttributeError:
		title_string = ""	

	return title_string

# Function to extract Product Price
def get_price(soup):

	try:
		price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()

	except AttributeError:

		try:
			# If there is some deal price
			price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

		except:		
			price = ""	

	return price

# Function to extract Product Rating
def get_rating(soup):

	try:
		rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
		
	except AttributeError:
		
		try:
			rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
		except:
			rating = ""	

	return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
	try:
		review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
		
	except AttributeError:
		review_count = ""	

	return review_count

# Function to extract Availability Status
def get_availability(soup):
	try:
		available = soup.find("div", attrs={'id':'availability'})
		available = available.find("span").string.strip()

	except AttributeError:
		available = "Not Available"	

	return available	


if __name__ == '__main__':

	# Headers for request
	HEADERS = ({'User-Agent':
	            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
	            'Accept-Language': 'en-US'})

	# The webpage URL
	URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"
	
	# HTTP Request
	webpage = requests.get(URL, headers=HEADERS)

	# Soup Object containing all data
	soup = BeautifulSoup(webpage.content, "lxml")

	# Fetch links as List of Tag Objects
	links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

	# Store the links
	links_list = []

	# Loop for extracting links from Tag Objects
	for link in links:
		links_list.append(link.get('href'))


	# Loop for extracting product details from each link 
	for link in links_list:

		new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

		new_soup = BeautifulSoup(new_webpage.content, "lxml")
		
		# Function calls to display all necessary product information
		print("Product Title =", get_title(new_soup))
		print("Product Price =", get_price(new_soup))
		print("Product Rating =", get_rating(new_soup))
		print("Number of Product Reviews =", get_review_count(new_soup))
		print("Availability =", get_availability(new_soup))
		print()
		print()
		df = df.append({'Product_Title':get_title(new_soup), 'Price':get_price(new_soup), 'Rating':get_rating(new_soup), 'Reviews':get_review_count(new_soup), 'Availability':get_availability(new_soup)}, ignore_index = True)

df.to_csv('MIRZAZA.csv')
# Out:
# Product Title =
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews =
# Availability = Not Available
#
#
# Product Title =
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews =
# Availability = Not Available
#
#
# Product Title =
# Product Price =
# Product Rating = 4.8 out of 5 stars
# Number of Product Reviews =
# Availability = Not Available
#
#
# Product Title =
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews =
# Availability = Not Available
#
#
# Product Title =
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews =
# Availability = Not Available
#
#
# Product Title =
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews =
# Availability = Not Available
#
#
# Product Title =
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews =
# Availability = Not Available
#
#
# Product Title =
# ...

# %%
#READ DATA
import pandas as pd
df=pd.read_csv("MIRZAZA.csv")
df
# Out:
#     Unnamed: 0                                      Product_Title  Price  \
# 0            0                                                NaN    NaN
# 1            1                                                NaN    NaN
# 2            2                                                NaN    NaN
# 3            3                                                NaN    NaN
# 4            4                                                NaN    NaN
# 5            5                                                NaN    NaN
# 6            6                                                NaN    NaN
# 7            7                                                NaN    NaN
# 8            8                                                NaN    NaN
# 9            9  Star Ocean The Divine Force PlayStation 4 with...    NaN
# 10          10  PlayStation 4 Move Motion Controller (Bulk Pac...    NaN
# 11          11             Sony Playstation PS4 1TB Black Console    NaN
# ...

# %%
# IMPORT NUMPY TO CREATE RANDOM VALUES
import numpy as np

# %%
data = np.random.randint(500,3000,size=35)

# %%
data
# Out:
# array([2678, 1911, 2445, 1672, 1684,  835, 1975, 2816,  610, 2674,  872,
#        1663,  904, 2781, 2480, 1399, 2405, 1949, 1113, 2889, 2705, 1218,
#        2679, 1599, 1138, 2845, 1716, 1770, 2246, 1031, 2782, 1710, 1994,
#        2400, 2224])

# %%
# CREATE NEW COLUMNS
df['Price_P'] =  np.random.randint(500,3000,size=len(df))

# %%
#DROP UNWANTED COLUMNS
to_drop=["Unnamed: 0","Price"]
df.drop(to_drop,axis=1,inplace=True)

# %%
df.head(2)
# Out:
#                                         Product_Title              Rating  \
# 9   Star Ocean The Divine Force PlayStation 4 with...  4.3 out of 5 stars
# 10  PlayStation 4 Move Motion Controller (Bulk Pac...  4.3 out of 5 stars
#
#         Reviews                        Availability  Price_P
# 9    84 ratings                            In Stock      710
# 10  598 ratings  Only 17 left in stock - order soon      539

# %%
df.dropna(inplace=True)

# %%
df['Rating'] = df['Rating'].str.replace('out of 5 stars', '')

# %%
df['Reviews'] = df['Reviews'].str.replace('ratings', '')

# %%
df.drop
# Out:
#                                         Product_Title Rating   Reviews  \
# 9   Star Ocean The Divine Force PlayStation 4 with...   4.3        84
# 10  PlayStation 4 Move Motion Controller (Bulk Pac...   4.3       598
# 11             Sony Playstation PS4 1TB Black Console   4.7     1,024
# 13  RPlay Play-Station 4 PS4 1TB Slim Edition Jet ...   4.8         8
# 14  Playstation Sony 4, 500GB Slim System [CUH-221...   4.5       307
# 15  PlayStation 4 500GB Console [Old Model][Discon...   4.6    13,654
# 16  Flagship Newest Play Station 4 1TB HDD Only on...   4.6       179
# 17  Sony PlayStation 4 Pro 1TB Console - Black (PS...   4.5     4,202
# 18             Sony PlayStation 4 Pro 1TB White (PS4)   4.4       938
# 19                    Sonic Frontiers - PlayStation 4   4.8       447
# 21  Hasbro Family Fun Pack - PlayStation 4 Standar...   4.5     2,706
# 23               PAC-MAN World Re-PAC - PlayStation 4   4.7       203
# ...

# %%
df.replace("Only"+ 1 + left in stock - order soon","Available")
# Out:
#   File "C:\Users\mirza\AppData\Local\Temp/ipykernel_11244/2608093460.py", line 1
#     df.replace("Only"+ 1 + left in stock - order soon","Available")
#                                                  ^
# SyntaxError: invalid syntax

# %%
# DATA CLEANING
for i in range(20):
    aa=("Only "+ str(i) + " left in stock - order soon","Available")
    print(aa)
    df.replace(aa,"Available",inplace=True)
# Out:
# ('Only 0 left in stock - order soon', 'Available')
# ('Only 1 left in stock - order soon', 'Available')
# ('Only 2 left in stock - order soon', 'Available')
# ('Only 3 left in stock - order soon', 'Available')
# ('Only 4 left in stock - order soon', 'Available')
# ('Only 5 left in stock - order soon', 'Available')
# ('Only 6 left in stock - order soon', 'Available')
# ('Only 7 left in stock - order soon', 'Available')
# ('Only 8 left in stock - order soon', 'Available')
# ('Only 9 left in stock - order soon', 'Available')
# ('Only 10 left in stock - order soon', 'Available')
# ('Only 11 left in stock - order soon', 'Available')
# ('Only 12 left in stock - order soon', 'Available')
# ('Only 13 left in stock - order soon', 'Available')
# ('Only 14 left in stock - order soon', 'Available')
# ('Only 15 left in stock - order soon', 'Available')
# ('Only 16 left in stock - order soon', 'Available')
# ('Only 17 left in stock - order soon', 'Available')
# ...

# %%
df.replace(aa,"Available")
# Out:
#                                         Product_Title Rating   Reviews  \
# 9   Star Ocean The Divine Force PlayStation 4 with...   4.3        84
# 10  PlayStation 4 Move Motion Controller (Bulk Pac...   4.3       598
# 11             Sony Playstation PS4 1TB Black Console   4.7     1,024
# 13  RPlay Play-Station 4 PS4 1TB Slim Edition Jet ...   4.8         8
# 14  Playstation Sony 4, 500GB Slim System [CUH-221...   4.5       307
# 15  PlayStation 4 500GB Console [Old Model][Discon...   4.6    13,654
# 16  Flagship Newest Play Station 4 1TB HDD Only on...   4.6       179
# 17  Sony PlayStation 4 Pro 1TB Console - Black (PS...   4.5     4,202
# 18             Sony PlayStation 4 Pro 1TB White (PS4)   4.4       938
# 19                    Sonic Frontiers - PlayStation 4   4.8       447
# 21  Hasbro Family Fun Pack - PlayStation 4 Standar...   4.5     2,706
# 23               PAC-MAN World Re-PAC - PlayStation 4   4.7       203
# ...
