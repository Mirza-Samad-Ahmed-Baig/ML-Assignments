# %% [markdown]
# # ML LAB 4 AND 5
# # MIRZA SAMAD 1790-2020
#  # QUESTION NUMBER 1

# %%
# LOAD REQUIRED LIBRARIES
import pandas as pd

# %% [markdown]
# # QUESTION NUMBER 2

# %%
# PUT HEADERS ON DATA
headers1=["sepal_length "
,"sepal_width "
,"petal_length "
,"petal_width "
,"class",]
df = pd.read_csv("iris.data",names=headers1)
df
# Out:
#      sepal_length   sepal_width   petal_length   petal_width            class
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # QUESTION NUMBER 3

# %%
df.head() # READ FIRST 5 LINES OF DATA
# Out:
#    sepal_length   sepal_width   petal_length   petal_width         class
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # QUESTION NUMBER 4

# %%
df.dtypes # READ DATA TYPES OF FEATURES
# Out:
# sepal_length     float64
# sepal_width      float64
# petal_length     float64
# petal_width      float64
# class             object
# dtype: object

# %% [markdown]
# # QUESTION NUMBER 5

# %%
print("MULTI CLASSES") # IT IS MULTICLASS
# Out:
# MULTI CLASSES

# %% [markdown]
# # QUESTION NUMBER 6

# %%
#Check if there are null values
nl=df.isnull()

# %%
# library to plot null values
import seaborn as sns

# %%
# plot null values
sns.heatmap(nl)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #  QUESTION NUMBER 7

# %%
#Fill null values with mean
df.fillna(value=df.mean, inplace=True)

# %% [markdown]
# # QUESTION NUMBER 8

# %%
#Drop null Values
df.dropna(inplace=True)

# %% [markdown]
# # QUESTION NUMBER 9

# %%
# Check mean std min count etc of features
df.describe()
# Out:
#        sepal_length   sepal_width   petal_length   petal_width
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # QUESTION NUMBER 10

# %%
# find unique values
# NO VALUE WITH 2 UNIQUE VALUES 
df.nunique()
df1=(pd.get_dummies(df))
df1
# Out:
#      sepal_length   sepal_width   petal_length   petal_width   \
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
#      class_Iris-setosa  class_Iris-versicolor  class_Iris-virginica
# 0                    1                      0                     0
# 1                    1                      0                     0
# ...

# %% [markdown]
# # QUESTION NUMBER 11

# %%
# normalize data between 0-1
from sklearn import preprocessing
MS = preprocessing.normalize(df1 )
scaled_df = pd.DataFrame(MS,columns=df1.columns)
scaled_df
# Out:
#      sepal_length   sepal_width   petal_length   petal_width   \
# 0         0.793973      0.544883       0.217953      0.031136
# 1         0.816553      0.499931       0.233301      0.033329
# 2         0.793765      0.540436       0.219552      0.033777
# 3         0.788198      0.531177       0.257021      0.034269
# 4         0.781250      0.562500       0.218750      0.031250
# ..             ...           ...            ...           ...
# 145       0.717409      0.321228       0.556795      0.246275
# 146       0.724809      0.287622       0.575245      0.218593
# 147       0.712225      0.328719       0.569780      0.219146
# 148       0.670711      0.367809       0.584168      0.248812
# 149       0.685583      0.348602       0.592623      0.209161
#
#      class_Iris-setosa  class_Iris-versicolor  class_Iris-virginica
# 0             0.155681                    0.0              0.000000
# 1             0.166644                    0.0              0.000000
# ...

# %%
df1["petal_length"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\ANACONDA\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# D:\ANACONDA\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\ANACONDA\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'petal_length'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
